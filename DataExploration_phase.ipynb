# %% [markdown]
# # Data Exploration Phase of the Project

# %%
# Add the Pandas dependency.
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import numpy as np
import seaborn as sns

# %%
# Files to load 
colorado_offense_to_load = "Resources/NIBRS_Offense_16_19.csv"
colorado_incidents_to_load = "Resources/Nibrs_incidents_16_19.csv"

# %%
# Read the NIBRS_Offense_16_19.csv file and store it in a Pandas DataFrame.
coloradoo_offense_df = pd.read_csv(colorado_offense_to_load)
coloradoo_offense_df
# Out:
#        ﻿DATA_YEAR  OFFENSE_ID  INCIDENT_ID OFFENSE_TYPE_ID  \
# 0            2019   139334487    114123065        Burglary
# 1            2019   139334534    114114955        Burglary
# 2            2019   139334535    114123107        Burglary
# 3            2019   139334609    114123161        Burglary
# 4            2019   139334842    114123327        Burglary
# ...           ...         ...          ...             ...
# 54925        2016   110071511     88333311        Burglary
# 54926        2016   110071516     88333323        Burglary
# 54927        2016   111154339     89270149        Burglary
# 54928        2016   111156846     89272462        Burglary
# 54929        2016   111154609     89270399        Burglary
#
#       ATTEMPT_COMPLETE_FLAG LOCATION_ID  NUM_PREMISES_ENTERED  \
# 0                         C   Residence                   NaN
# 1                         C   Residence                   NaN
# 2                         C   Residence                   NaN
# ...

# %%
#Examine the Data
coloradoo_offense_df.dtypes
# Out:
# ﻿DATA_YEAR                 int64
# OFFENSE_ID                 int64
# INCIDENT_ID                int64
# OFFENSE_TYPE_ID           object
# ATTEMPT_COMPLETE_FLAG     object
# LOCATION_ID               object
# NUM_PREMISES_ENTERED     float64
# METHOD_ENTRY_CODE         object
# dtype: object

# %%
# Read the DenverCrime file and store it in a Pandas DataFrame.
colorado_incidents_df = pd.read_csv(colorado_incidents_to_load)
colorado_incidents_df
# Out:
#        ﻿DATA_YEAR  AGENCY_ID  INCIDENT_ID  NIBRS_MONTH_ID CARGO_THEFT_FLAG  \
# 0            2019       1843    119315957         8211278                N
# 1            2019       1934    120342638         8188360                N
# 2            2019       1934    119338351         8211346                N
# 3            2019       1934    120347122         8196022                N
# 4            2019       1895    119342240         8226637                N
# ...           ...        ...          ...             ...              ...
# 54925        2016       1988     84455340         7172501                N
# 54926        2016       1988     84463618         7286421                N
# 54927        2016       1988     84460568         7240853                N
# 54928        2016       1988     84460577         7240853                N
# 54929        2016       1988     84453387         7172501                N
#
#        SUBMISSION_DATE INCIDENT_DATE INCIDENT_Month  INCIDENT_DAY  \
# ...

# %%
# Examine the data
colorado_incidents_df.dtypes
# Out:
# ﻿DATA_YEAR            int64
# AGENCY_ID             int64
# INCIDENT_ID           int64
# NIBRS_MONTH_ID        int64
# CARGO_THEFT_FLAG     object
# SUBMISSION_DATE     float64
# INCIDENT_DATE        object
# INCIDENT_Month       object
# INCIDENT_DAY          int64
# REPORT_DATE_FLAG     object
# INCIDENT_HOUR       float64
# DATA_HOME            object
# ORIG_FORMAT          object
# DID                 float64
# dtype: object

# %% [markdown]
# ### Summary of Descriptive Statistics - Colorado Offense

# %%
#Create a new Series to hold Descriptip Descriptive Statistics - ColoradoStateCrime
coloradoo_offense_df.describe()
# Out:
#          ﻿DATA_YEAR    OFFENSE_ID   INCIDENT_ID  NUM_PREMISES_ENTERED
# count  54930.000000  5.493000e+04  5.493000e+04                8033.0
# mean    2017.470453  1.222486e+08  9.935107e+07                   0.0
# std        1.077294  1.276673e+07  1.102940e+07                   0.0
# min     2016.000000  1.041232e+08  8.282222e+07                   0.0
# 25%     2017.000000  1.120350e+08  9.003887e+07                   0.0
# 50%     2017.000000  1.198179e+08  9.684797e+07                   0.0
# 75%     2018.000000  1.324770e+08  1.079872e+08                   0.0
# max     2019.000000  1.486611e+08  1.228647e+08                   0.0

# %%
offense_df_sns=sns.load_dataset("Resources/NIBRS_Offense_16_19.csv")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-14-b92e7479d148> in <module>
# ----> 1 offense_df_sns=sns.load_dataset("Resources/NIBRS_Offense_16_19.csv")
#
# ~\anaconda3\envs\mlenv\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     447                                   os.path.basename(full_path))
#     448         if not os.path.exists(cache_path):
# --> 449             urlretrieve(full_path, cache_path)
#     450         full_path = cache_path
#     451
#
# ~\anaconda3\envs\mlenv\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = _splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ...

# %% [markdown]
# ### Summary of Descriptive Statistics - Colorado Incidents

# %%
#Create a new Series to hold Descriptip Descriptive Statistics - ColoradoStateCrime
colorado_incidents_df.describe()
# Out:
#          ﻿DATA_YEAR     AGENCY_ID   INCIDENT_ID  NIBRS_MONTH_ID  \
# count  54930.000000  54930.000000  5.493000e+04    5.493000e+04
# mean    2017.470453   1993.491826  9.935107e+07    7.834692e+06
# std        1.077294    732.885642  1.102940e+07    4.011602e+05
# min     2016.000000   1826.000000  8.282222e+07    7.126772e+06
# 25%     2017.000000   1866.000000  9.003887e+07    7.558810e+06
# 50%     2017.000000   1958.000000  9.684797e+07    7.863485e+06
# 75%     2018.000000   2077.000000  1.079872e+08    8.173128e+06
# max     2019.000000  25314.000000  1.228647e+08    9.276086e+06
#
#        SUBMISSION_DATE  INCIDENT_DAY  INCIDENT_HOUR           DID
# count      46695.00000  54930.000000   53935.000000  4.669500e+04
# mean       43470.33661     15.659021      12.027681  2.866555e+07
# std          187.57388      8.841023       6.431655  1.981503e+07
# min        43329.00000      1.000000       0.000000  1.385539e+06
# ...

# %%
#Import dataframes to Module20_finalproject database
from sqlalchemy import create_engine

# %%
postimport = "postgres://postgres:sch00lZZpostgresql@127.0.0.1:5432/Module20_finalproject"

# %%
engine=create_engine(postimport)

# %%
colorado_incidents_df.to_sql(name="nibrs_incident",con=engine)

# %%
#colorado_incidents_16_df.to_sql(name="nibrs_incident",con=engine)

# %%
coloradoo_offense_df.to_sql(name="nibrs_offense",con=engine)
