# %% [markdown]
# # Data Exploration Phase of the Project

# %%
# Add the Pandas dependency.
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import numpy as np

# %%
# Files to load 
ColoradoStateCrime_to_load = "Resources/ColoradoStateCrime_09_19.csv"
DenverCrime_to_load = "Resources/DenverCrime.csv"

# %%
# Read the ColoradoStateCrime file and store it in a Pandas DataFrame.
ColoradoStateCrime_df = pd.read_csv(ColoradoStateCrime_to_load)
ColoradoStateCrime_df
# Out:
#                              Location Type Incident Hour of Day  \
# 0                           Residence/Home                Night
# 1                           Residence/Home                Night
# 2                           Residence/Home                Night
# 3                           Residence/Home                Night
# 4                           Residence/Home                Night
# ...                                    ...                  ...
# 5179  Government/Public Building and other                  Day
# 5180  Government/Public Building and other                  Day
# 5181  Government/Public Building and other                  Day
# 5182  Government/Public Building and other                  Day
# 5183  Government/Public Building and other                  Day
#
#      Incident Month Offense Attempted or Completed  Number of Crimes  Year  \
# 0           January                      Attempted                 1  2015
# ...

# %%
# Read the DenverCrime file and store it in a Pandas DataFrame.
DenverCrime_df = pd.read_csv(DenverCrime_to_load)
DenverCrime_df
# Out:
#        INCIDENT_ID    OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0        201985551  2.020000e+14          2203                       0
# 1       2017443179  2.020000e+15          2204                       0
# 2       2017248008  2.020000e+15          2204                       0
# 3       2017533019  2.020000e+15          2204                       0
# 4       2019315865  2.020000e+15          2204                       0
# ...            ...           ...           ...                     ...
# 21994   2020176458  2.020000e+15          2204                       0
# 21995   2020255311  2.020000e+15          2202                       0
# 21996   2020322915  2.020000e+15          2204                       0
# 21997   2020272897  2.020000e+15          2203                       0
# 21998   2020352117  2.020000e+15          2204                       0
#
#                    OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID Incident Hour of Day  \
# ...

# %% [markdown]
# ### Summary of Descriptive Statistics - Colorado State Crime

# %%
#Create a new Series to hold Descriptip Descriptive Statistics - ColoradoStateCrime
ColoradoStateCrime_df.describe()
# Out:
#        Number of Crimes         Year  Crime Rate (per 1,000)  \
# count       5184.000000  5184.000000             4146.000000
# mean          43.831404  2014.555556                0.009619
# std           94.282087     3.143000                0.019727
# min            0.000000  2009.000000                0.000000
# 25%            1.000000  2012.000000                0.000000
# 50%            6.000000  2015.000000                0.000000
# 75%           30.000000  2017.000000                0.010000
# max          595.000000  2019.000000                0.110000
#
#        Crime Rate (per 100,000)  Offense Rate (per 1,000)  \
# count               4146.000000               4146.000000
# mean                   1.024170                  0.009619
# std                    1.934321                  0.019727
# min                    0.020000                  0.000000
# 25%                    0.060000                  0.000000
# 50%                    0.180000                  0.000000
# ...

# %% [markdown]
# ### Summary of Descriptive Statistics - City of Denver Crime

# %%
#Create a new Series to hold Descriptip Descriptive Statistics - ColoradoStateCrime
DenverCrime_df.describe()
# Out:
#         INCIDENT_ID    OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# count  2.199900e+04  2.199900e+04  21999.000000            21999.000000
# mean   1.976516e+09  1.978512e+15   1987.698986                0.027638
# std    1.833028e+09  1.834779e+15    410.681341                0.163936
# min    2.017676e+06  2.020000e+12   1202.000000                0.000000
# 25%    2.016528e+09  2.020000e+15   2202.000000                0.000000
# 50%    2.017654e+09  2.020000e+15   2203.000000                0.000000
# 75%    2.018767e+09  2.020000e+15   2204.000000                0.000000
# max    2.020602e+10  2.020000e+16   2206.000000                1.000000
#
#        Number of Crimes  FIRST_OCCURRENCE_YEAR         GEO_X         GEO_Y  \
# count           21999.0           21999.000000  2.199900e+04  2.199900e+04
# mean                1.0            2017.450930  3.161129e+06  1.693178e+06
# std                 0.0               1.118548  6.198970e+05  1.526077e+05
# ...
